# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
mydb = myclient["Douyin"]

# %%
users = mydb.users

# %%
users
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'Douyin'), 'users')

# %%
user = users.find_one()

# %%
user
# Out:
# {'_id': ObjectId('5de09ff01b9be34699ef37b5'),
#  'status_code': 0,
#  'user': {'follower_status': 0,
#   'react_setting': 0,
#   'relative_users': None,
#   'verify_info': '',
#   'mplatform_followers_count': 131392,
#   'comment_setting': 0,
#   'share_qrcode_uri': '2413d00001882721808f4',
#   'has_unread_story': False,
#   'gender': 0,
#   'weibo_schema': '',
#   'prevent_download': False,
#   'duet_setting': 0,
#   'follower_count': 131392,
#   'activity': {'use_music_count': 0, 'digg_count': 0},
#   'is_block': False,
#   'room_id': 0,
#   'region': 'CN',
#   'recommend_reason_relation': '',
#   'is_verified': True,
#   'ins_id': '',
#   'live_commerce': False,
#   'dp_level': False,
#   'share_info': {'share_desc': '在抖音，记录美好生活！',
#    'share_title': '快来加入抖音，让你发现最有趣的我！',
#    'share_qrcode_url': {'uri': '2413d00001882721808f4',
#     'url_list': ['https://p1-dy.byteimg.com/obj/2413d00001882721808f4',
#      'https://p3-dy.byteimg.com/obj/2413d00001882721808f4',
#      'https://p9-dy.byteimg.com/obj/2413d00001882721808f4']},
#    'share_image_url': {'url_list': None},
#    'bool_persist': 1,
#    'share_url': 'www.iesdouyin.com/share/user/1270684175830861?sec_uid=MS4wLjABAAAA3a_qLxKyySo1O8kWTyIry7J-L1aYoYkJxX8qhdmRdVpqFNRwo_3mF43dptHooBA4',
#    'share_weibo_desc': '在抖音，记录美好生活！'},
#   'need_points': None,
#   'custom_verify': '',
#   'bind_phone': '#',
#   'reflow_page_gid': 0,
#   'country': '中国',
#   'location': '北京',
#   'user_canceled': False,
#   'district': '朝阳',
#   'type_label': None,
#   'show_image_bubble': False,
#   'is_gov_media_vip': False,
#   'content_language_already_popup': 0,
#   'video_cover': {},
#   'story_open': False,
#   'item_list': None,
#   'cover_url': [{'uri': 'c8510002be9a3a61aad2',
#     'url_list': ['https://p9-dy.byteimg.com/obj/c8510002be9a3a61aad2',
#      'https://p1-dy.byteimg.com/obj/c8510002be9a3a61aad2',
#      'https://p3-dy.byteimg.com/obj/c8510002be9a3a61aad2']}],
#   'account_region': '',
#   'original_musician': {'music_count': 0,
#    'music_used_count': 0,
#    'digg_count': 0},
#   'birthday_hide_level': 0,
#   'urge_detail': {'user_urged': 0},
#   'special_lock': 1,
#   'user_story_count': 0,
#   'ad_cover_url': None,
#   'with_commerce_enterprise_tab_entry': False,
#   'latest_order_time': 0,
#   'with_new_goods': False,
#   'unique_id': 'Wu1591055785',
#   'verification_type': 0,
#   'enterprise_verify_reason': '',
#   'user_mode': 0,
#   'is_effect_artist': False,
#   'nickname': '娱乐工兵',
#   'constellation': 4,
#   'avatar_larger': {'uri': '2d6c2000642ccea81906b',
#    'url_list': ['https://p3-dy.byteimg.com/aweme/1080x1080/2d6c2000642ccea81906b.jpeg',
#     'https://p9-dy.byteimg.com/aweme/1080x1080/2d6c2000642ccea81906b.jpeg',
#     'https://p1-dy.byteimg.com/aweme/1080x1080/2d6c2000642ccea81906b.jpeg']},
#   'aweme_count': 278,
#   'weibo_verify': '',
#   'twitter_name': '',
#   'hide_following_follower_list': 0,
#   'is_blocked': False,
#   'commerce_user_info': {},
#   'signature': '青春飞扬！与明星近距离对话',
#   'youtube_refresh_token': '',
#   'city': '北京',
#   'avatar_thumb': {'uri': '2d6c2000642ccea81906b',
#    'url_list': ['https://p3-dy.byteimg.com/aweme/100x100/2d6c2000642ccea81906b.jpeg',
#     'https://p9-dy.byteimg.com/aweme/100x100/2d6c2000642ccea81906b.jpeg',
#     'https://p1-dy.byteimg.com/aweme/100x100/2d6c2000642ccea81906b.jpeg']},
#   'favoriting_count': 878,
#   'weibo_url': '',
#   'with_stick_entry': True,
#   'avatar_medium': {'uri': '2d6c2000642ccea81906b',
#    'url_list': ['https://p3-dy.byteimg.com/aweme/720x720/2d6c2000642ccea81906b.jpeg',
#     'https://p9-dy.byteimg.com/aweme/720x720/2d6c2000642ccea81906b.jpeg',
#     'https://p1-dy.byteimg.com/aweme/720x720/2d6c2000642ccea81906b.jpeg']},
#   'youtube_channel_id': '',
#   'dongtai_count': 190,
#   'avatar_uri': '2d6c2000642ccea81906b',
#   'reflow_page_uid': 0,
#   'video_icon_virtual_URI': '',
#   'secret': 0,
#   'r_fans_group_info': {},
#   'cha_list': None,
#   'is_pro_account': False,
#   'has_activity_medal': False,
#   'is_activity_user': False,
#   'download_prompt_ts': 0,
#   'commerce_user_level': 0,
#   'geofencing': None,
#   'video_icon': {'uri': '', 'url_list': []},
#   'profile_tab_type': 0,
#   'avatar_300x300': {'uri': '2d6c2000642ccea81906b',
#    'url_list': ['http://p3-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~300x300.webp',
#     'http://p9-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~300x300.webp',
#     'http://p1-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~300x300.webp']},
#   'wx_tag': 0,
#   'followers_detail': [{'app_name': 'aweme',
#     'name': '抖音',
#     'icon': 'http://p3.pstatp.com/origin/50ec00079b64de2050dc',
#     'fans_count': 131392,
#     'open_url': 'snssdk1128://user/profile/1270684175830861?',
#     'apple_id': '1142110895',
#     'download_url': 'https://d.douyin.com/JsvN/',
#     'package_name': 'com.ss.android.ugc.aweme'},
#    {'icon': 'http://p3.pstatp.com/origin/50ed00079a1b6b8d1fb1',
#     'fans_count': 0,
#     'open_url': 'snssdk143://profile?uid=1270684175830861',
#     'apple_id': '529092160',
#     'download_url': 'https://d.toutiao.com/YjjY/',
#     'package_name': 'com.ss.android.article.news',
#     'app_name': 'news_article',
#     'name': '头条'},
#    {'package_name': 'com.ss.android.ugc.live',
#     'app_name': 'live_stream',
#     'name': '火山',
#     'icon': 'http://p3.pstatp.com/origin/551900041a7e00ec86ca',
#     'fans_count': 0,
#     'open_url': 'snssdk1112://profile?id=1270684175830861',
#     'apple_id': '1086047750',
#     'download_url': 'http://d.huoshanzhibo.com/eFvB/'}],
#   'watch_status': False,
#   'sec_uid': 'MS4wLjABAAAA3a_qLxKyySo1O8kWTyIry7J-L1aYoYkJxX8qhdmRdVpqFNRwo_3mF43dptHooBA4',
#   'youtube_last_refresh_time': 0,
#   'unique_id_modify_time': 1575002096,
#   'short_id': '0',
#   'follow_status': 0,
#   'following_count': 64,
#   'with_commerce_entry': False,
#   'user_period': 0,
#   'with_luban_entry': False,
#   'uid': '1270684175830861',
#   'twitter_id': '',
#   'apple_account': 0,
#   'youtube_channel_title': '',
#   'has_insights': False,
#   'new_story_cover': None,
#   'platform_sync_info': None,
#   'star_use_new_download': True,
#   'download_setting': 0,
#   'iso_country_code': 'CN',
#   'avatar_168x168': {'uri': '2d6c2000642ccea81906b',
#    'url_list': ['http://p3-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~168x168.webp',
#     'http://p9-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~168x168.webp',
#     'http://p1-dy.byteimg.com/img/mosaic-legacy/2d6c2000642ccea81906b~168x168.webp']},
#   'school_poi_id': '',
#   'hide_location': False,
#   'with_shop_entry': False,
#   'with_fusion_shop_entry': False,
#   'province': '',
#   'signature_language': 'zh',
#   'total_favorited': 4670964,
#   'has_story': False,
#   'is_star': False,
#   'sync_to_toutiao': 0,
#   'birthday': '1994-01-01'},
#  'extra': {'now': 1575002096000},
#  'log_pb': {'impr_id': '201911291234560100140400340111F673'}}

# %%
aggs = [
    {
        "$group":{
            "_id": "$user.gender",
            "count": {"$sum":1},
            "avg_dongtai_count": {"$avg":"$user.dongtai_count"}
        }
    }
]

result = users.aggregate(pipeline=aggs)

# %%
for i in result:
    print(i)
# Out:
# {'_id': 0, 'count': 16930, 'avg_dongtai_count': 128.5743650324867}
# {'_id': 1, 'count': 60790, 'avg_dongtai_count': 136.6423424905412}
# {'_id': None, 'count': 2681, 'avg_dongtai_count': None}
# {'_id': 2, 'count': 91532, 'avg_dongtai_count': 128.63200847790935}

# %% [markdown]
# 在user属性中发现了is_star字段，对其进行聚合统计的结果如下，虽然不知道背后的设置标准，但是我们可以初步使用此字段进行“大V&粉丝”之间的区分

# %%
match = {'$match': {'user.is_star': {'$ne': None},
                     'user.gender': {'$ne': None},
                     'user.follower_count': {'$gt': 100000},
                     'user.following_count': {'$ne': None},
                     'user.total_favorited': {'$ne': None}}}  
            
group = {"$group":{
            "_id": {"is_star":"$user.is_star"},
            "count": {"$sum":1},
            "avg_follower_count": {"$avg":"$user.follower_count"},
            "max_follower_count": {"$max":"$user.follower_count"},
            "min_follower_count": {"$min":"$user.follower_count"},
            "avg_following_count": {"$avg":"$user.following_count"},
            "max_following_count": {"$max":"$user.following_count"},
            "min_following_count": {"$min":"$user.following_count"},
            "avg_total_favorited": {"$avg":"$user.total_favorited"},
            "max_total_favorited": {"$max":"$user.total_favorited"},
            "min_total_favorited": {"$min":"$user.total_favorited"},
            "avg_dongtai_count": {"$avg":"$user.dongtai_count"},
            "max_dongtai_count": {"$max":"$user.dongtai_count"},
            "min_dongtai_count": {"$min":"$user.dongtai_count"}
        }
    }

pipeline = [match, group]

result = users.aggregate(pipeline)

for i in result:
    print(i)
# Out:
# {'_id': {'is_star': True}, 'count': 655, 'avg_follower_count': 3246280.53740458, 'max_follower_count': 82817696, 'min_follower_count': 103530, 'avg_following_count': 46.581679389312974, 'max_following_count': 4967, 'min_following_count': 0, 'avg_total_favorited': 13979801.390839694, 'max_total_favorited': 444484832, 'min_total_favorited': 99370, 'avg_dongtai_count': 62.196946564885494, 'max_dongtai_count': 1346, 'min_dongtai_count': 1}
# {'_id': {'is_star': False}, 'count': 45892, 'avg_follower_count': 683074.3314956855, 'max_follower_count': 64792560, 'min_follower_count': 100006, 'avg_following_count': 181.78584502745576, 'max_following_count': 9637, 'min_following_count': 0, 'avg_total_favorited': 6463977.5416194545, 'max_total_favorited': 1035081536, 'min_total_favorited': -2147483648, 'avg_dongtai_count': 219.23771027630087, 'max_dongtai_count': 12970, 'min_dongtai_count': 0}

# %% [markdown]
# ##### 结论：
#
# 1. 明星的受关注度明显高于非明星，具体体现为follower更多，following更少，favorited更多
# 2. 网红并不包括在明星之中，理由是非明星也拥有十分可观的平均流量，这与现实情况并不匹配
# 3. 添加maxmin分析后发现，非明星中的大V，即网红，在流量表现上并不逊色于明星
# 4. 使用粉丝数大于100000进行筛选后，非明星的平均数据表现向明星逼近
#
#
# ##### 那么问题来了
#
# Q:如何划定标准区分出网红？
#
# A:【简单方案】粉丝数和受赞数混合筛选

# %%
import pandas as pd

df = pd.DataFrame(list(users.find()))

# %%
df_data = []
for user in users.find():
    df_data.append(user['user'])

# %%
df = pd.DataFrame(df_data)

# %%
df = df[['is_star', 'gender', 'birthday', 'follower_count', 'following_count', 'total_favorited', 'dongtai_count',
       'with_shop_entry', 'commerce_user_level', 'type_label']]

# %%
df = df[df.is_star == False]
df = df[(df.birthday >= '1919-01-01') & (df.birthday <= '2013-01-01')]
df = df[df.follower_count < 10000]
df = df[df.total_favorited < 1000000]

# %%
df.head()
# Out:
#    is_star  gender    birthday  follower_count  following_count  \
# 9    False     2.0  1990-01-01          1375.0              8.0
# 11   False     1.0  1986-01-01          1238.0             57.0
# 20   False     1.0  1990-01-01          2584.0            282.0
# 22   False     2.0  1988-01-01          1309.0           1802.0
# 24   False     2.0  1993-01-01          4996.0             10.0
#
#     total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 9           13455.0           51.0           False                  0.0
# 11         147722.0          133.0           False                  0.0
# 20          80489.0           13.0           False                  0.0
# 22          51898.0           30.0           False                  0.0
# 24         383162.0            6.0           False                  0.0
#
#     type_label
# 9          NaN
# 11         NaN
# 20         NaN
# 22         NaN
# 24         NaN

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

df.groupby([df.birthday]).is_star.count().plot(kind="bar")

plt.xlabel("")
ax=plt.gca()
counter = 0
for label in ax.get_xticklabels():
    if counter%4 != 0:
        label.set_visible(False)
    counter += 1
plt.show()

# %%
df.groupby([df.gender]).is_star.count().plot(kind="bar")

plt.xlabel("")
ax=plt.gca()
plt.show()

# %%
df.groupby([df.commerce_user_level]).is_star.count().plot(kind="bar")

plt.xlabel("")
ax=plt.gca()
plt.show()

# %%
df_withcommerce = df[df.commerce_user_level == 1]

# %%
df_withcommerce.head()
# Out:
#      is_star  gender    birthday  follower_count  following_count  \
# 1129   False     1.0  2000-01-01          9071.0            714.0
# 1390   False     1.0  1997-01-01          9029.0             92.0
# 1552   False     2.0  1979-01-01          4072.0             52.0
# 2370   False     2.0  1993-01-01          3964.0            159.0
# 2383   False     2.0  1995-01-01          9240.0              0.0
#
#       total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 1129          56669.0          262.0           False                  1.0
# 1390          67807.0           26.0           False                  1.0
# 1552          81397.0           70.0           False                  1.0
# 2370          88431.0           71.0           False                  1.0
# 2383          62201.0           18.0           False                  1.0
#
#       type_label
# 1129         NaN
# 1390         NaN
# 1552         NaN
# 2370         NaN
# 2383         NaN

# %%
df_withcommerce.groupby([df_withcommerce.birthday]).is_star.count().plot(kind="bar")

plt.xlabel("")
ax=plt.gca()
counter = 0
for label in ax.get_xticklabels():
    if counter%4 != 0:
        label.set_visible(False)
    counter += 1
plt.show()

# %%
df_withcommerce.groupby([df_withcommerce.gender]).is_star.count().plot(kind="bar")
plt.show()

# %% [markdown]
# commerce_user_level等于1的用户从年龄分布上来看，大多数为80后90后，对应经济活动最频繁的一群人，猜想会和卖东西有关

# %%
df.groupby([df.with_shop_entry]).is_star.count().plot(kind="bar")
plt.show()

# %% [markdown]
# 现在回到全部数据对commerce和shop进行统计

# %%
df = pd.DataFrame(df_data)
df = df[['is_star', 'gender', 'birthday', 'follower_count', 'following_count', 'total_favorited', 'dongtai_count',
       'with_shop_entry', 'commerce_user_level', 'type_label']]

# %%
df.groupby([df.commerce_user_level]).is_star.count().plot(kind="bar")
plt.show()

# %%
df.groupby([df.commerce_user_level]).is_star.count()
# Out:
# commerce_user_level
# 0.0    158767
# 1.0     10270
# 2.0       215
# Name: is_star, dtype: int64

# %%
df_withcommerce_1 = df[df.commerce_user_level == 1]
df_withcommerce_2 = df[df.commerce_user_level == 2]

# %%
df_withcommerce_1.head()
# Out:
#     is_star  gender    birthday  follower_count  following_count  \
# 3     False     2.0  2014-01-01        146219.0              4.0
# 16    False     1.0  2011-01-01       2706115.0              2.0
# 63    False     1.0  1992-01-01        811078.0            167.0
# 65    False     1.0  1996-01-01      13994834.0            125.0
# 126   False     1.0  2019-01-01        308784.0             35.0
#
#      total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 3          1684085.0          103.0           False                  1.0
# 16        19549202.0          342.0           False                  1.0
# 63         3356110.0          614.0           False                  1.0
# 65       199360192.0          356.0           False                  1.0
# 126        6145403.0          745.0           False                  1.0
#
#      type_label
# 3           NaN
# 16          NaN
# 63          NaN
# 65          NaN
# 126         NaN

# %%
df_withcommerce_2.head()
# Out:
#      is_star  gender    birthday  follower_count  following_count  \
# 420    False     1.0  1991-01-01        741486.0              8.0
# 723    False     1.0                    257995.0             14.0
# 836    False     2.0  1992-01-01        618102.0              2.0
# 1127   False     0.0  2004-01-01       8061765.0             56.0
# 1182   False     2.0  2001-01-01        406768.0             22.0
#
#       total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 420         9670515.0          191.0           False                  2.0
# 723         2984836.0          135.0           False                  2.0
# 836        26146138.0          625.0           False                  2.0
# 1127       68586592.0          268.0           False                  2.0
# 1182        1509252.0          141.0           False                  2.0
#
#       type_label
# 420          NaN
# 723          NaN
# 836          NaN
# 1127         NaN
# 1182         NaN

# %%
df_withcommerce_2.follower_count
# Out:
# 420        741486.0
# 723        257995.0
# 836        618102.0
# 1127      8061765.0
# 1182       406768.0
#             ...
# 163911     111115.0
# 165796      18721.0
# 170173     640263.0
# 170875      11018.0
# 171163      26452.0
# Name: follower_count, Length: 215, dtype: float64

# %%
min(df_withcommerce_1.follower_count)
# Out:
# 0.0

# %%
min(df_withcommerce_2.follower_count)
# Out:
# 10491.0

# %%
df_withcommerce_1.groupby([df_withcommerce_1.with_shop_entry]).is_star.count().plot(kind="bar")
plt.show()

# %%
df_withcommerce_1.groupby([df_withcommerce_1.with_shop_entry]).is_star.count()
# Out:
# with_shop_entry
# False    10263
# True         7
# Name: is_star, dtype: int64

# %%
df_withcommerce_2.groupby([df_withcommerce_2.with_shop_entry]).is_star.count()
# Out:
# with_shop_entry
# False    215
# Name: is_star, dtype: int64

# %%
df_withshop = df[df.with_shop_entry == True]

# %%
df_withshop.head()
# Out:
#      is_star  gender    birthday  follower_count  following_count  \
# 430    False     1.0  1989-01-01       2156663.0            390.0
# 573    False     2.0  1986-01-01       2984629.0             33.0
# 743    False     2.0  2013-01-01        329572.0             32.0
# 2526   False     1.0  0907-01-01       1765128.0            525.0
# 2714   False     2.0  1497-01-01       3684503.0            174.0
#
#       total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 430        11205367.0          951.0            True                  0.0
# 573        12554129.0          452.0            True                  0.0
# 743         3982718.0          238.0            True                  0.0
# 2526        9739565.0          201.0            True                  0.0
# 2714       32635490.0          200.0            True                  0.0
#
#       type_label
# 430          NaN
# 573          NaN
# 743          NaN
# 2526         NaN
# 2714         NaN

# %%
df_withcommerce_1.groupby([df_withcommerce_1.birthday]).is_star.count().plot(kind="bar")

ax=plt.gca()
counter = 0
for label in ax.get_xticklabels():
    if counter%4 != 0:
        label.set_visible(False)
    counter += 1
plt.show()

# %%
df_withcommerce_2.groupby([df_withcommerce_2.birthday]).is_star.count().plot(kind="bar")

ax=plt.gca()
counter = 0
for label in ax.get_xticklabels():
    if counter%4 != 0:
        label.set_visible(False)
    counter += 1
plt.show()

# %%
df_withshop.groupby([df_withshop.birthday]).is_star.count().plot(kind="bar")

ax=plt.gca()
counter = 0
for label in ax.get_xticklabels():
    if counter%4 != 0:
        label.set_visible(False)
    counter += 1
plt.show()

# %%
df_withshop
# Out:
#        is_star  gender    birthday  follower_count  following_count  \
# 430      False     1.0  1989-01-01       2156663.0            390.0
# 573      False     2.0  1986-01-01       2984629.0             33.0
# 743      False     2.0  2013-01-01        329572.0             32.0
# 2526     False     1.0  0907-01-01       1765128.0            525.0
# 2714     False     2.0  1497-01-01       3684503.0            174.0
# 2929     False     2.0  2016-01-01       2333039.0             14.0
# 4911     False     2.0  2015-01-01        469689.0            208.0
# 5336     False     1.0  1991-01-01       3724734.0             90.0
# 6016     False     1.0  2015-01-01       1627498.0             46.0
# 8524     False     2.0  2018-01-01        969339.0             45.0
# 14012    False     1.0  2017-01-01       1027250.0             50.0
# 15333    False     2.0  1900-01-01       1364383.0             25.0
# 15383    False     2.0  1994-01-01        207459.0             35.0
# 15581    False     2.0  1900-01-01       1236619.0             23.0
# 19397    False     1.0  1985-01-01       1865095.0             10.0
# 23358    False     1.0  1987-01-01        179502.0              9.0
# 25965    False     2.0  2008-01-01       3267655.0             56.0
# 30577    False     2.0                    586732.0            168.0
# 32139    False     0.0                   1660600.0            150.0
# 37311    False     1.0  1996-01-01       2841658.0            238.0
# 40948    False     1.0  1984-01-01        264967.0            388.0
# 42758    False     1.0  1900-01-01        953570.0             29.0
# 45842    False     2.0  2000-01-01       1401749.0              9.0
# 48086    False     1.0  1990-01-01        358465.0             69.0
# 53918    False     2.0  1990-01-01       2837826.0             11.0
# 57784    False     2.0  1997-01-01        892922.0             39.0
# 62408    False     1.0                   2045547.0              3.0
# 62583    False     2.0  1995-01-01       1301737.0            166.0
# 64675    False     1.0  1996-01-01        541630.0             38.0
# 67652    False     1.0  1993-01-01       3538010.0            114.0
# 71184    False     1.0  1989-01-01         69587.0              8.0
# 73979    False     1.0  2014-01-01        484578.0            195.0
# 75534    False     2.0  1995-01-01       4758438.0              3.0
# 78022    False     2.0                    347581.0            271.0
# 79655    False     2.0  1918-01-01       2386257.0              4.0
# 82057    False     2.0  2017-01-01        685000.0             23.0
# 83767    False     1.0  2000-01-01        421628.0              7.0
# 90782    False     1.0  1986-01-01        119174.0             86.0
# 95199    False     2.0                    883417.0              4.0
# 107192   False     1.0  1992-01-01       2213168.0             93.0
# 122174   False     0.0                    239440.0             28.0
# 127510   False     2.0  1996-01-01        330945.0             44.0
# 136028   False     2.0                   1805597.0             74.0
# 136537   False     1.0  1979-01-01        499833.0             25.0
# 158027   False     0.0  2018-01-01        401999.0             40.0
#
#         total_favorited  dongtai_count with_shop_entry  commerce_user_level  \
# 430          11205367.0          951.0            True                  0.0
# 573          12554129.0          452.0            True                  0.0
# 743           3982718.0          238.0            True                  0.0
# 2526          9739565.0          201.0            True                  0.0
# 2714         32635490.0          200.0            True                  0.0
# 2929          5613128.0          383.0            True                  1.0
# 4911          4975330.0          393.0            True                  0.0
# 5336         47709768.0          283.0            True                  0.0
# 6016          7067807.0          285.0            True                  0.0
# 8524          7749820.0          181.0            True                  0.0
# 14012         9589426.0          225.0            True                  0.0
# 15333         6178799.0          363.0            True                  0.0
# 15383         2283317.0          327.0            True                  0.0
# 15581         5600204.0          363.0            True                  0.0
# 19397         8475379.0          648.0            True                  0.0
# 23358         3286987.0          362.0            True                  0.0
# 25965        19340299.0          467.0            True                  0.0
# 30577         2240453.0          325.0            True                  1.0
# 32139        11460075.0          412.0            True                  0.0
# 37311        29576927.0          318.0            True                  0.0
# 40948          703490.0         1505.0            True                  1.0
# 42758         2487431.0          567.0            True                  1.0
# 45842        25372048.0          192.0            True                  0.0
# 48086          788732.0          503.0            True                  0.0
# 53918        22420617.0          378.0            True                  0.0
# 57784         3218176.0          186.0            True                  0.0
# 62408         3466068.0           76.0            True                  0.0
# 62583         7969979.0          339.0            True                  0.0
# 64675         5471518.0          250.0            True                  0.0
# 67652        18188690.0          348.0            True                  0.0
# 71184          235100.0          613.0            True                  1.0
# 73979         5410309.0          559.0            True                  0.0
# 75534        92759392.0          300.0            True                  0.0
# 78022         1573650.0          108.0            True                  0.0
# 79655        14522270.0          177.0            True                  0.0
# 82057         4372770.0          423.0            True                  0.0
# 83767         1332080.0          907.0            True                  1.0
# 90782          867845.0          135.0            True                  1.0
# 95199         2800740.0           25.0            True                  0.0
# 107192       14099927.0          208.0            True                  0.0
# 122174        1142498.0           70.0            True                  0.0
# 127510        3399291.0          281.0            True                  0.0
# 136028       16191769.0         1887.0            True                  0.0
# 136537        1230062.0          888.0            True                  0.0
# 158027        4098034.0          251.0            True                  0.0
#
#         type_label
# 430            NaN
# 573            NaN
# 743            NaN
# 2526           NaN
# 2714           NaN
# 2929           NaN
# 4911           NaN
# 5336           NaN
# 6016           NaN
# 8524           NaN
# 14012          NaN
# 15333          NaN
# 15383          NaN
# 15581          NaN
# 19397          NaN
# 23358          NaN
# 25965          NaN
# 30577          NaN
# 32139          NaN
# 37311          NaN
# 40948          NaN
# 42758          NaN
# 45842          NaN
# 48086          NaN
# 53918          NaN
# 57784          NaN
# 62408          NaN
# 62583          NaN
# 64675          NaN
# 67652          NaN
# 71184          NaN
# 73979          NaN
# 75534          NaN
# 78022          NaN
# 79655          NaN
# 82057          NaN
# 83767          NaN
# 90782          NaN
# 95199          NaN
# 107192         NaN
# 122174         NaN
# 127510         NaN
# 136028         NaN
# 136537         NaN
# 158027         NaN
